# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df=pd.read_csv("FinalDataset.csv")
df
# Out:
#     Year          Subject  Total  1 Mark  2 Marks  Total Number of questions
# 0   2005  Data Structures     12       4        4                          8
# 1   2005    Digital Logic      2       2        0                          2
# 2   2005             Math     17       5        6                         11
# 3   2005               OS      9       3        3                          6
# 4   2005      Programming      5       1        2                          3
# ..   ...              ...    ...     ...      ...                        ...
# 80  2021  Data Structures      8       2        3                          5
# 81  2021    Digital Logic      4       2        1                          3
# 82  2021             Math     17       5        6                         11
# 83  2021               OS      5       3        1                          4
# 84  2021      Programming      3       1        1                          2
#
# [85 rows x 6 columns]

# %%
profile= ProfileReport(df)
profile.to_file(output_file="report.pdf")
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\SR\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:266: UserWarning: Extension .pdf not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt

# %%
df1=pd.read_excel("Book1.xlsx")

# %%
df1
# Out:
#     Year      Subject           Topic  1 mark questions  2 marks questions  \
# 0   2020  Mathematics   Engg Maths II                 2                  2
# 1   2020  Mathematics  Engg Maths III                 3                  0
# 2   2019  Mathematics    Engg Maths I                 2                  0
# 3   2019  Mathematics   Engg Maths II                 2                  0
# 4   2019  Mathematics  Engg Maths III                 1                  2
# 5   2018  Mathematics    Engg Maths I                 3                  1
# 6   2018  Mathematics   Engg Maths II                 1                  0
# 7   2018  Mathematics  Engg Maths III                 2                  1
# 8   2017  Mathematics    Engg Maths I                 1                  2
# 9   2017  Mathematics   Engg Maths II                 1                  2
# 10  2017  Mathematics  Engg Maths III                 2                  1
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Engg Maths I'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-cfeab9d0b46c> in <module>
# ----> 1 abc=df1.loc['Engg Maths I']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
# ...
